# %% [markdown]
# # Utilisation de pandas

# %%
import numpy as np
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
#Définir un objet Series comprenant la population de 5 pays 
ser1=Series([70,40,8,300],index=["France","Espagne","Suisse","USA"])

#ser1=Series({"France":70,"Espagne":40,"Suisse":8,"USA":300})

#puis afficher les pays ayant une population > 50’000’000.
list(ser1[ser1<50].index)
# Out:
# ['Espagne', 'Suisse']

# %%
ser1.index.get_indexer_non_unique(list(ser1[ser1<50].index))
# Out:
# (Int64Index([1, 2], dtype='int64'), array([], dtype=int64))

# %%
#Définir les noms de l’objet et de la colonne des pays pour la Series précédente
ser1.name="Populations"
ser1.index.name="Pays"
ser1.to_csv("ser1.csv",decimal=",",sep=";")

# %%
import webbrowser
url='https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records'
webbrowser.open(url)
# Out:
# True

# %%
frame1=pd.read_clipboard()

# %%
frame1
# Out:
#     Rank                    Team    Won   Lost   Pct. First NBA Season  \
# 0      1       San Antonio Spurs  2,006  1,226  0.621          1976–77
# 1      2      Los Angeles Lakers  3,235  2,134  0.603          1948–49
# 2      3          Boston Celtics  3,221  2,257  0.588          1946–47
# 3      4            Phoenix Suns  2,122  1,766  0.546          1968–69
# 4      5   Oklahoma City Thunder  2,139  1,831  0.539          1967–68
# 5      6  Portland Trail Blazers  1,991  1,733  0.535          1970–71
# 6      7               Utah Jazz  1,815  1,581  0.534          1974–75
# 7      8           Chicago Bulls  2,115  1,936  0.522          1966–67
# 8      9              Miami Heat  1,170  1,078  0.520          1988–89
# 9     10         Houston Rockets  2,052  1,918  0.517          1967–68
# 10    11      Philadelphia 76ers  2,726  2,578  0.514          1949–50
# 11    12        Dallas Mavericks  1,482  1,422  0.510          1980–81
# ...

# %%
frame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
# Rank                30 non-null int64
# Team                30 non-null object
# Won                 30 non-null object
# Lost                30 non-null object
# Pct.                30 non-null float64
# First NBA Season    30 non-null object
# Total Games         30 non-null object
# Division            30 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.0+ KB

# %%
frame1.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Pct.', 'First NBA Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
frame1["Rank"]
frame1.Rank
frame1[["Rank","Won"]]
# Out:
#     Rank    Won
# 0      1  2,006
# 1      2  3,235
# 2      3  3,221
# 3      4  2,122
# 4      5  2,139
# 5      6  1,991
# 6      7  1,815
# 7      8  2,115
# 8      9  1,170
# 9     10  2,052
# 10    11  2,726
# 11    12  1,482
# 12    13  1,983
# 13    14  2,650
# 14    15  1,606
# 15    16  2,701
# 16    17  1,062
# 17    18  2,616
# 18    19  1,563
# 19    20  2,590
# 20    21    528
# 21    22  1,728
# 22    23  2,464
# 23    24  2,004
# 24    25    916
# 25    26    734
# 26    27  1,360
# 27    28    694
# 28    29  1,469
# 29    30    847

# %%
for name in ['Won', 'Lost','Total Games']:
    frame1[name]=frame1[name].str.replace(",","")
    frame1[name]=frame1[name].astype(dtype=float)

# %%
frame1.describe()
frame1.median()
frame1.quantile(0.975)
frame1.corr()
# Out:
#                  Rank       Won      Lost      Pct.  Total Games
# Rank         1.000000 -0.568841 -0.065044 -0.969359    -0.351810
# Won         -0.568841  1.000000  0.824618  0.600164     0.961872
# Lost        -0.065044  0.824618  1.000000  0.074978     0.947893
# Pct.        -0.969359  0.600164  0.074978  1.000000     0.374254
# Total Games -0.351810  0.961872  0.947893  0.374254     1.000000

# %%
#extraire une colonne
frame1[[3]]
frame1[["Won","Lost"]]
frame1[["Won"]]
# Out:
#        Won
# 0   2006.0
# 1   3235.0
# 2   3221.0
# 3   2122.0
# 4   2139.0
# 5   1991.0
# 6   1815.0
# 7   2115.0
# 8   1170.0
# 9   2052.0
# 10  2726.0
# 11  1482.0
# 12  1983.0
# 13  2650.0
# 14  1606.0
# 15  2701.0
# 16  1062.0
# 17  2616.0
# 18  1563.0
# 19  2590.0
# 20   528.0
# 21  1728.0
# 22  2464.0
# 23  2004.0
# 24   916.0
# 25   734.0
# 26  1360.0
# 27   694.0
# 28  1469.0
# 29   847.0

# %%
#Construire deux frames avec quelques colonnes et lignes en commun puis 
#combinez-les.

frame2=DataFrame(np.random.randn(6).reshape(2,3),index=["obs1","obs2"],columns=["A","B","C"])
frame3=DataFrame(np.random.randn(6).reshape(2,3),index=["obs1","obs2"],columns=["A","B","D"])

# %%
frame2+frame3
# Out:
#              A         B   C   D
# obs1 -0.102618 -1.014003 NaN NaN
# obs2  2.545570 -0.688695 NaN NaN

# %%
frame2.add(frame3,fill_value=0)
# Out:
#              A         B         C         D
# obs1 -0.102618 -1.014003 -0.455364  0.119713
# obs2  2.545570 -0.688695 -0.909810  1.468412

# %%
frame2
# Out:
#           A         B         C
# 0  1.347689 -1.447655 -0.645977
# 1  0.081567 -0.913928 -1.296691

# %%
frame1.sort_values(["Division","Won"],ascending=[True,False],inplace=True)

# %%
frame1
# Out:
#     Rank                    Team     Won    Lost   Pct. First NBA Season  \
# 2      3          Boston Celtics  3221.0  2257.0  0.588          1946–47
# 10    11      Philadelphia 76ers  2726.0  2578.0  0.514          1949–50
# 15    16         New York Knicks  2701.0  2774.0  0.493          1946–47
# 26    27           Brooklyn Nets  1360.0  1872.0  0.421          1976–77
# 25    26         Toronto Raptors   734.0   940.0  0.438          1995–96
# 17    18         Detroit Pistons  2616.0  2752.0  0.487          1948–49
# 7      8           Chicago Bulls  2115.0  1936.0  0.522          1966–67
# 12    13         Milwaukee Bucks  1983.0  1905.0  0.510          1968–69
# 21    22     Cleveland Cavaliers  1728.0  1996.0  0.464          1970–71
# 14    15          Indiana Pacers  1606.0  1625.0  0.497          1976–77
# 4      5   Oklahoma City Thunder  2139.0  1831.0  0.539          1967–68
# 5      6  Portland Trail Blazers  1991.0  1733.0  0.535          1970–71
# ...

# %%
ser2 = Series(np.random.randn(6),index=[[1,1,1,2,2,2],['a','b','c','a','b','c']])

# %%
ser2
# Out:
# 1  a    0.862369
#    b    0.413786
#    c   -1.736558
# 2  a    0.815326
#    b   -0.673509
#    c   -0.665682
# dtype: float64

# %%
ser2.unstack()
# Out:
#           a         b         c
# 1  0.862369  0.413786 -1.736558
# 2  0.815326 -0.673509 -0.665682

# %%
#Importez le fichier demo_ventes.csv depuis Python dans FrameVentes.
frameVentes=pd.read_csv("demo_ventes.csv",sep=";")

# %%
frameVentes
# Out:
#     account     Jan     Feb     Mar
# 0    211829   10000   62000   35000
# 1    320563   95000   45000   35000
# 2    648336   91000  120000   35000
# 3    109996   45000  120000   10000
# 4    121213  162000  120000   35000
# 5    132971  150000  120000   35000
# 6    145068   62000  120000   70000
# 7    205217  145000   95000   35000
# 8    209744   70000   95000   35000
# 9    212303   70000  120000   35000
# 10   214098   45000  120000   55000
# 11   231907  150000   10000  162000
# 12   242368  162000  120000   35000
# 13   268755   55000  120000   35000
# 14   273274  150000  120000   70000

# %%
#Importez un fichier Excel depuis python. On utilisera excel-data.xlsx
#on crée un objet classeur Excel
classeurExcel=pd.ExcelFile("excel-data.xlsx")

# %%
classeurExcel.sheet_names
# Out:
# ['sheet1']

# %%
#on extrait une feuille du classeur et on la met dans un DataFrame
frameExcel=classeurExcel.parse("sheet1")

# %%
frameExcel
#autre approche :
frameExcel=pd.read_excel("excel-data.xlsx",sheetname="sheet1")

# %%
frameExcel
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
#Importez la base de données SQLite salaries et récupérez la table Salaries 
# dans un DataFrame 
from sqlalchemy import create_engine

# %%
engine=create_engine('sqlite:///salaries.sqlite')

# %%
engine.table_names()
# Out:
# ['Salaries']

# %%
frameSalaries=pd.read_sql_query("SELECT * from Salaries", engine)

# %%
frameSalaries.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
groupJob=frameSalaries.groupby("JobTitle")

# %%
frameSalaries.dropna().sample(n=5000).to_excel("test.xlsx")

# %%
groupJob.agg(['mean','std'])
groupJob.describe().to_csv("sortie.csv")

# %%
frameSalaries["TotalPay"].median()
# Out:
# 71426.60999999999

# %%
groupJob.agg(['mean','std'])
# Out:
#                                                                Id  \
#                                                              mean
# JobTitle
# ACCOUNT CLERK                                        25734.819277
# ACCOUNTANT                                           24159.200000
# ACCOUNTANT INTERN                                    28128.833333
# ACPO,JuvP, Juv Prob (SFERS)                         135284.000000
# ACUPUNCTURIST                                        18379.000000
# ADMINISTRATIVE ANALYST                               19052.946237
# ADMINISTRATIVE ANALYST II                            20542.000000
# ADMINISTRATIVE ANALYST III                           11020.500000
# ADMINISTRATIVE ENGINEER                               4781.800000
# ADMINISTRATIVE SERVICES MANAGER                      15777.000000
# ADMINISTRATOR, SFGH MEDICAL CENTER                      37.000000
# AFFIRMATIVE ACTION SPECIALIST                        17343.833333
# ...

# %%
#jointure
frame4=pd.merge(frameExcel,frameVentes,on="account")

# %%
#discrétisation
#taille égale
pd.cut(frame4["Jan"],bins=5)
#intervalles sur mesure
pd.cut(frame4["Jan"],bins=[float("-inf"),10000,20000,100000,float("inf")])
#effectif égaux
pd.qcut(frame4["Jan"],5).value_counts()
# Out:
# (1.15e+05, 150000]    4
# (53000, 70000]        4
# [10000, 53000]        3
# (150000, 162000]      2
# (70000, 1.15e+05]     2
# Name: Jan, dtype: int64

# %%
#dates
#Créez un objet Series et ajoutez des dates partant du 3 décembre 2015 par jour jusqu’à aujourd’hui.
ser3=Series(np.random.randn(366),
            index=pd.date_range("2016-01-01","2016-12-31",freq='d'))

# %%
ser3
# Out:
# 2016-01-01   -0.353019
# 2016-01-02    0.011045
# 2016-01-03    0.222369
# 2016-01-04    0.754328
# 2016-01-05    1.230859
# 2016-01-06   -0.816883
# 2016-01-07    0.287068
# 2016-01-08   -0.495295
# 2016-01-09    0.113107
# 2016-01-10    0.092274
# 2016-01-11   -0.215029
# 2016-01-12   -0.948605
# 2016-01-13   -0.570478
# 2016-01-14    1.679276
# 2016-01-15   -0.383736
# 2016-01-16   -0.342687
# 2016-01-17   -0.577783
# 2016-01-18    1.013334
# 2016-01-19   -0.591503
# 2016-01-20   -0.459229
# 2016-01-21    0.293055
# 2016-01-22   -0.356748
# 2016-01-23   -0.367567
# 2016-01-24    0.856503
# 2016-01-25    0.316590
# 2016-01-26   -0.713084
# 2016-01-27    1.673357
# 2016-01-28    1.271690
# 2016-01-29    1.381500
# 2016-01-30   -0.630857
#                 ...
# 2016-12-02   -0.596118
# 2016-12-03    0.556168
# 2016-12-04    0.380543
# 2016-12-05   -1.263677
# 2016-12-06   -0.490873
# 2016-12-07    0.090059
# 2016-12-08    0.467318
# 2016-12-09    2.384507
# 2016-12-10   -0.536906
# ...
